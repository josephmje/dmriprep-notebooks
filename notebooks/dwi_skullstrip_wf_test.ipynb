# %%
import os

from bids import BIDSLayout
from nipype.pipeline import engine as pe
from nipype.interfaces import mrtrix3, fsl, utility as niu

# %%
def init_bet_frac_wf(frac=0.3):
    wf = pe.Workflow(name='bet_frac_wf')
    
    inputnode = pe.Node(niu.IdentityInterface(fields=['dwi_file',
                                                      'bvec_file',
                                                      'bval_file']), 
                        name='inputnode')
    
    outputnode = pe.Node(niu.IdentityInterface(fields=['out_file']), name='outputnode')

    def b0_average(in_dwi, in_bval, b0_thresh=0, out_file=None):

        import os
        import numpy as np
        import nibabel as nib
        from nipype.utils import NUMPY_MMAP
        from nipype.utils.filemanip import fname_presuffix

        if out_file is None:
            out_file = fname_presuffix(
                in_dwi, suffix='_avg_b0', newpath=os.path.abspath('.')
            )

        imgs = np.array(nib.four_to_three(nib.load(in_dwi, mmap=NUMPY_MMAP)))
        bval = np.loadtxt(in_bval)
        index = np.argwhere(bval <= b0_thresh).flatten().tolist()

        b0s = [im.get_data().astype(np.float32) for im in imgs[index]]
        b0 = np.average(np.array(b0s), axis=0)

        hdr = imgs[0].header.copy()
        hdr.set_data_shape(b0.shape)
        hdr.set_xyzt_units('mm')
        hdr.set_data_dtype(np.float32)
        nib.Nifti1Image(b0, imgs[0].affine, hdr).to_filename(out_file)
        return out_file

    avg_b0_0 = pe.Node(
        niu.Function(
            input_names=['in_dwi', 'in_bval', 'b0_thresh'],
            output_names=['out_file'],
            function=b0_average),
        name='b0_avg_pre')

    bet_dwi0 = pe.Node(
        fsl.BET(frac=frac, mask=True, robust=True),
        name='bet_dwi_pre')
    
    wf.connect(
        [(inputnode, avg_b0_0, [('dwi_file', 'in_dwi'),
                                ('bval_file', 'in_bval')]),
         (avg_b0_0, bet_dwi0, [('out_file', 'in_file')]),
         (bet_dwi0, outputnode, [('out_file', 'out_file')])
        ]
    )
    
    return wf

# %%
def init_bet_func_wf():
    wf = pe.Workflow(name='bet_func_wf')
    
    inputnode = pe.Node(niu.IdentityInterface(fields=['dwi_file',
                                                      'bvec_file',
                                                      'bval_file']), 
                        name='inputnode')
    
    outputnode = pe.Node(niu.IdentityInterface(fields=['out_file']), name='outputnode')

    def b0_average(in_dwi, in_bval, b0_thresh=0, out_file=None):

        import os
        import numpy as np
        import nibabel as nib
        from nipype.utils import NUMPY_MMAP
        from nipype.utils.filemanip import fname_presuffix

        if out_file is None:
            out_file = fname_presuffix(
                in_dwi, suffix='_avg_b0', newpath=os.path.abspath('.')
            )

        imgs = np.array(nib.four_to_three(nib.load(in_dwi, mmap=NUMPY_MMAP)))
        bval = np.loadtxt(in_bval)
        index = np.argwhere(bval <= b0_thresh).flatten().tolist()

        b0s = [im.get_data().astype(np.float32) for im in imgs[index]]
        b0 = np.average(np.array(b0s), axis=0)

        hdr = imgs[0].header.copy()
        hdr.set_data_shape(b0.shape)
        hdr.set_xyzt_units('mm')
        hdr.set_data_dtype(np.float32)
        nib.Nifti1Image(b0, imgs[0].affine, hdr).to_filename(out_file)
        return out_file

    avg_b0_0 = pe.Node(
        niu.Function(
            input_names=['in_dwi', 'in_bval', 'b0_thresh'],
            output_names=['out_file'],
            function=b0_average),
        name='b0_avg_pre')

    bet_dwi0 = pe.Node(
        fsl.BET(mask=True, functional=True),
        name='bet_dwi_pre')

    wf.connect(
        [(inputnode, avg_b0_0, [('dwi_file', 'in_dwi'),
                                ('bval_file', 'in_bval')]),
         (avg_b0_0, bet_dwi0, [('out_file', 'in_file')]),
         (bet_dwi0, outputnode, [('out_file', 'out_file')])
        ]
    )
    
    return wf

# %%
def init_median_otsu_wf():
    wf = pe.Workflow(name='median_otsu_wf')
    
    inputnode = pe.Node(niu.IdentityInterface(fields=['dwi_file',
                                                      'bvec_file',
                                                      'bval_file']), 
                        name='inputnode')
    
    outputnode = pe.Node(niu.IdentityInterface(fields=['out_file']), name='outputnode')

    def b0_average(in_dwi, in_bval, b0_thresh=0, out_file=None):

        import os
        import numpy as np
        import nibabel as nib
        from nipype.utils import NUMPY_MMAP
        from nipype.utils.filemanip import fname_presuffix

        if out_file is None:
            out_file = fname_presuffix(
                in_dwi, suffix='_avg_b0', newpath=os.path.abspath('.')
            )

        imgs = np.array(nib.four_to_three(nib.load(in_dwi, mmap=NUMPY_MMAP)))
        bval = np.loadtxt(in_bval)
        index = np.argwhere(bval <= b0_thresh).flatten().tolist()

        b0s = [im.get_data().astype(np.float32) for im in imgs[index]]
        b0 = np.average(np.array(b0s), axis=0)

        hdr = imgs[0].header.copy()
        hdr.set_data_shape(b0.shape)
        hdr.set_xyzt_units('mm')
        hdr.set_data_dtype(np.float32)
        nib.Nifti1Image(b0, imgs[0].affine, hdr).to_filename(out_file)
        return out_file

    avg_b0_0 = pe.Node(
        niu.Function(
            input_names=['in_dwi', 'in_bval', 'b0_thresh'],
            output_names=['out_file'],
            function=b0_average),
        name='b0_avg_pre')
    
    def get_b0_mask_fn(b0_file):
        import os
        import nibabel as nib
        from nipype.utils.filemanip import fname_presuffix
        from dipy.segment.mask import median_otsu

        mask_file = fname_presuffix(
            b0_file, suffix='_mask', newpath=os.path.abspath('.')
        )
        img = nib.load(b0_file)
        data, aff = img.get_data(), img.affine
        brain, mask = median_otsu(data, 2, 1)
        nib.Nifti1Image(mask.astype(float), aff).to_filename(mask_file)
        return brain, mask_file
    
    b0mask_node = pe.Node(
        niu.Function(
            input_names=['b0_file'],
            output_names=['brain_file', 'mask_file'],
            function=get_b0_mask_fn),
        name='getB0Mask')

    wf.connect(
        [(inputnode, avg_b0_0, [('dwi_file', 'in_dwi'),
                                ('bval_file', 'in_bval')]),
         (avg_b0_0, b0mask_node, [('out_file', 'b0_file')]),
         (b0mask_node, outputnode, [('brain_file', 'out_file')])
        ]
    )
    
    return wf

# %%
def init_dwi2mask_wf():
    wf = pe.Workflow(name='dwi2mask_wf')
    
    inputnode = pe.Node(niu.IdentityInterface(fields=['dwi_file',
                                                      'bvec_file',
                                                      'bval_file']), 
                        name='inputnode')
    
    outputnode = pe.Node(niu.IdentityInterface(fields=['out_file']), name='outputnode')
  
    bias_correct = pe.Node(mrtrix3.DWIBiasCorrect(use_ants=True), name='bias_correct')
    
    b0mask_node = pe.Node(mrtrix3.BrainMask(), name='b0mask_node')
    
    wf.connect(
        [(inputnode, bias_correct, [('dwi_file', 'in_file'),
                                    ('bvec_file', 'in_bvec'),
                                    ('bval_file', 'in_bval')]),
         (bias_correct, b0mask_node, [('out_file', 'in_file')]),
         (inputnode, b0mask_node, [('bvec_file', 'in_bvec'),
                                   ('bval_file', 'in_bval')]),
         (b0mask_node, outputnode, [('out_file', 'out_file')])
        ]
    )
    
    return wf

# %%
data_dir = os.path.abspath('../data')
layout = BIDSLayout(data_dir)

# %%
dwi_files = layout.get(datatype='dwi', extension=['nii.gz', 'nii'], return_type='file')
dwi_file = dwi_files[0]
bvec_file = layout.get_bvec(dwi_file)
bval_file = layout.get_bval(dwi_file)

# %%
workflows = [init_bet_frac_wf(), init_bet_func_wf(), init_median_otsu_wf(), init_dwi2mask_wf()]

# %%
mrtrix3.BrainMask()

# %%
for test_wf in workflows:
    test_wf.base_dir = os.path.join(os.getcwd(), 'skullstrip')

    inputspec = test_wf.get_node('inputnode')
    inputspec.inputs.dwi_file = dwi_file
    inputspec.inputs.bval_file = bval_file
    inputspec.inputs.bvec_file = bvec_file

    test_wf.write_graph(graph2use='colored')
    test_wf.config['execution']['remove_unnecessary_outputs'] = False
    test_wf.config['execution']['keep_inputs'] = True
    test_wf.config['execution']['crashfile_format'] = 'txt'

    test_wf.run()
# Out:
# 190830-16:43:00,34 nipype.workflow INFO:
# 	 Generated workflow graph: /mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/bet_frac_wf/graph.png (graph2use=colored, simple_form=True).
# 190830-16:43:00,173 nipype.workflow INFO:
# 	 Workflow bet_frac_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 190830-16:43:00,208 nipype.workflow INFO:
# 	 Running serially.
# 190830-16:43:00,210 nipype.workflow INFO:
# 	 [Node] Setting-up "bet_frac_wf.b0_avg_pre" in "/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/bet_frac_wf/b0_avg_pre".
# 190830-16:43:00,219 nipype.workflow INFO:
# 	 [Node] Cached "bet_frac_wf.b0_avg_pre" - collecting precomputed outputs
# 190830-16:43:00,221 nipype.workflow INFO:
# 	 [Node] "bet_frac_wf.b0_avg_pre" found cached.
# 190830-16:43:00,222 nipype.workflow INFO:
# 	 [Node] Setting-up "bet_frac_wf.bet_dwi_pre" in "/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/bet_frac_wf/bet_dwi_pre".
# 190830-16:43:00,234 nipype.workflow INFO:
# 	 [Node] Cached "bet_frac_wf.bet_dwi_pre" - collecting precomputed outputs
# 190830-16:43:00,235 nipype.workflow INFO:
# 	 [Node] "bet_frac_wf.bet_dwi_pre" found cached.
# 190830-16:43:00,409 nipype.workflow INFO:
# 	 Generated workflow graph: /mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/bet_func_wf/graph.png (graph2use=colored, simple_form=True).
# 190830-16:43:00,412 nipype.workflow INFO:
# 	 Workflow bet_func_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 190830-16:43:00,438 nipype.workflow INFO:
# 	 Running serially.
# 190830-16:43:00,440 nipype.workflow INFO:
# 	 [Node] Setting-up "bet_func_wf.b0_avg_pre" in "/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/bet_func_wf/b0_avg_pre".
# 190830-16:43:00,476 nipype.workflow INFO:
# 	 [Node] Cached "bet_func_wf.b0_avg_pre" - collecting precomputed outputs
# 190830-16:43:00,477 nipype.workflow INFO:
# 	 [Node] "bet_func_wf.b0_avg_pre" found cached.
# 190830-16:43:00,478 nipype.workflow INFO:
# 	 [Node] Setting-up "bet_func_wf.bet_dwi_pre" in "/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/bet_func_wf/bet_dwi_pre".
# 190830-16:43:00,490 nipype.workflow INFO:
# 	 [Node] Cached "bet_func_wf.bet_dwi_pre" - collecting precomputed outputs
# 190830-16:43:00,491 nipype.workflow INFO:
# 	 [Node] "bet_func_wf.bet_dwi_pre" found cached.
# 190830-16:43:00,659 nipype.workflow INFO:
# 	 Generated workflow graph: /mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/median_otsu_wf/graph.png (graph2use=colored, simple_form=True).
# 190830-16:43:00,662 nipype.workflow INFO:
# 	 Workflow median_otsu_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 190830-16:43:00,688 nipype.workflow INFO:
# 	 Running serially.
# 190830-16:43:00,690 nipype.workflow INFO:
# 	 [Node] Setting-up "median_otsu_wf.b0_avg_pre" in "/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/median_otsu_wf/b0_avg_pre".
# 190830-16:43:00,699 nipype.workflow INFO:
# 	 [Node] Cached "median_otsu_wf.b0_avg_pre" - collecting precomputed outputs
# 190830-16:43:00,700 nipype.workflow INFO:
# 	 [Node] "median_otsu_wf.b0_avg_pre" found cached.
# 190830-16:43:00,701 nipype.workflow INFO:
# 	 [Node] Setting-up "median_otsu_wf.getB0Mask" in "/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/median_otsu_wf/getB0Mask".
# 190830-16:43:00,748 nipype.workflow INFO:
# 	 [Node] Cached "median_otsu_wf.getB0Mask" - collecting precomputed outputs
# 190830-16:43:00,749 nipype.workflow INFO:
# 	 [Node] "median_otsu_wf.getB0Mask" found cached.
# 190830-16:43:00,951 nipype.workflow INFO:
# 	 Generated workflow graph: /mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/dwi2mask_wf/graph.png (graph2use=colored, simple_form=True).
# 190830-16:43:00,954 nipype.workflow INFO:
# 	 Workflow dwi2mask_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 190830-16:43:00,981 nipype.workflow INFO:
# 	 Running serially.
# 190830-16:43:00,983 nipype.workflow INFO:
# 	 [Node] Setting-up "dwi2mask_wf.bias_correct" in "/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/dwi2mask_wf/bias_correct".
# 190830-16:43:00,992 nipype.workflow INFO:
# 	 [Node] Cached "dwi2mask_wf.bias_correct" - collecting precomputed outputs
# 190830-16:43:00,994 nipype.workflow INFO:
# 	 [Node] "dwi2mask_wf.bias_correct" found cached.
# 190830-16:43:00,995 nipype.workflow INFO:
# 	 [Node] Setting-up "dwi2mask_wf.b0mask_node" in "/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/dwi2mask_wf/b0mask_node".
# 190830-16:43:01,93 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 190830-16:43:01,99 nipype.workflow WARNING:
# 	 [Node] Error on "dwi2mask_wf.b0mask_node" (/mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/skullstrip/dwi2mask_wf/b0mask_node)
# 190830-16:43:01,115 nipype.workflow ERROR:
# 	 Node b0mask_node failed to run on host noether.camhres.ca.
# 190830-16:43:01,124 nipype.workflow ERROR:
# 	 Saving crash info to /mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/crash-20190830-164301-mjoseph-b0mask_node-67d37c17-fbcd-4a59-92ce-10bda5e2fab6.txt
# Traceback (most recent call last):
#   File "/scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/pipeline/plugins/linear.py", line 48, in run
#     node.run(updatehash=updatehash)
#   File "/scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/pipeline/engine/nodes.py", line 473, in run
#     result = self._run_interface(execute=True)
#   File "/scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/pipeline/engine/nodes.py", line 564, in _run_interface
#     return self._run_command(execute)
#   File "/scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/pipeline/engine/nodes.py", line 635, in _run_command
#     cmd = self._interface.cmdline
#   File "/scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/interfaces/base/core.py", line 677, in cmdline
#     allargs = [self._cmd_prefix + self.cmd] + self._parse_inputs()
#   File "/scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/interfaces/base/core.py", line 926, in _parse_inputs
#     arg = self._format_arg(name, spec, value)
#   File "/scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/interfaces/base/core.py", line 801, in _format_arg
#     return argstr % value
# TypeError: not enough arguments for format string
#
# 190830-16:43:01,130 nipype.workflow INFO:
# 	 ***********************************
# 190830-16:43:01,131 nipype.workflow ERROR:
# 	 could not run node: dwi2mask_wf.b0mask_node
# 190830-16:43:01,132 nipype.workflow INFO:
# 	 crashfile: /mnt/tigrlab/projects/mjoseph/pipelines/dmriprep-notebooks/notebooks/crash-20190830-164301-mjoseph-b0mask_node-67d37c17-fbcd-4a59-92ce-10bda5e2fab6.txt
# 190830-16:43:01,132 nipype.workflow INFO:
# 	 ***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-d2b65ac3a951> in <module>
#      12     test_wf.config['execution']['crashfile_format'] = 'txt'
#      13
# ---> 14     test_wf.run()
#
# /scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     597         if str2bool(self.config['execution']['create_report']):
#     598             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 599         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     600         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     601         if str2bool(self.config['execution']['write_provenance']):
#
# /scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/pipeline/plugins/linear.py in run(self, graph, config, updatehash)
#      69
#      70         os.chdir(old_wd)  # Return wherever we were before
# ---> 71         report_nodes_not_run(notrun)
#
# /scratch/mjoseph/.pyenv/versions/dwi_venv/lib/python3.7/site-packages/nipype-1.2.2.dev0+gf32c9b1fa-py3.7.egg/nipype/pipeline/plugins/tools.py in report_nodes_not_run(notrun)
#      80                 logger.debug(subnode._id)
#      81         logger.info("***********************************")
# ---> 82         raise RuntimeError(('Workflow did not execute cleanly. '
#      83                             'Check log for details'))
#      84
#
# RuntimeError: Workflow did not execute cleanly. Check log for details
